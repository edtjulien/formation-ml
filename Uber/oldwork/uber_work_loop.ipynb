# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook"
from sklearn.cluster import KMeans, MiniBatchKMeans, DBSCAN
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import numpy as np

pio.renderers.default = "notebook"

# %%
# Constants
INPUT_FILE_NAME = "uber-raw-data-apr14.csv"
OUTPUT_FILE_NAME = "output/uber-clusters2.csv"
MAP_COLOR_SCALE = ['#323aa8','#db1616','#26ab26']

# %%
df = pd.read_csv(INPUT_FILE_NAME)

# %%
# we create new features using datetime column
date_col_name = "Date/Time"
df[date_col_name] = pd.to_datetime(df[date_col_name])
df['dayofweek'] = df[date_col_name].dt.day_of_week
df['hour'] = df[date_col_name].dt.hour

df = df.drop([date_col_name, 'Base'], axis=1)
# we rename columns
df = df.rename({'Lat':'lat','Lon':'lon'}, axis=1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer

# we fit a scaller that will user later to transform our df

numerical_features = ['lat','lon']
numerical_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

categorical_features = ['dayofweek','hour']
categorical_transformer = Pipeline(
    steps=[
    ('encoder', OneHotEncoder(drop='first'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])

preprocessor.fit(df)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('scaler', StandardScaler())]),
#                                  ['lat', 'lon']),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(drop='first'))]),
#                                  ['dayofweek', 'hour'])])

# %%
# generic function to fit Kmeans, MiniBatchKmeans and DBSCAN models
# the function apply the preprocessing and return the dataframe with clusters data as new column
def fit_cluster(X_hour:pd.DataFrame, model='kmeans', n_clusters=5, eps=0.2, min_samples=100):
  X_hour_scaled = preprocessor.transform(X_hour) # on standardise
  if model == 'kmeansfast':
    cluster = MiniBatchKMeans(n_clusters=n_clusters, random_state=0)
  elif model == 'kmeans':
    cluster = KMeans(n_clusters=n_clusters, random_state=0)
  elif model == 'dbscan':
    cluster = DBSCAN(eps=eps, min_samples=min_samples, n_jobs=-1)
  else:
    raise Exception("model need values: kmeans, kmeansfast, dbscan")
  cluster.fit(X_hour_scaled) # on fit notre kmean
  X_hour['clusters'] = cluster.labels_
  return X_hour

# %%
# on découpe le dataset 7 x 24 = 168 dataframes
new_df = df.drop(df.index)
new_df['clusters'] = None
for d in range(0,7):
  for h in range(0,24):
    small_df = df.loc[(df['dayofweek'] == d) & (df['hour'] == h),:].reset_index(drop=True)

    size = small_df.shape[0]
    min_samples = int(size * 0.009)
    print(f'Day {d}, Hour {h} : ', size, f', min_samples: {min_samples}')

    small_df = fit_cluster(small_df.copy(), model='dbscan', eps=0.3, min_samples=min_samples) # small df with clusters

    new_df = pd.concat([new_df,small_df])
# Out:
# Day 0, Hour 0 :  518 , min_samples: 4
# Day 0, Hour 1 :  261 , min_samples: 2
# Day 0, Hour 2 :  238 , min_samples: 2
# Day 0, Hour 3 :  571 , min_samples: 5
# Day 0, Hour 4 :  1021 , min_samples: 9
# Day 0, Hour 5 :  1619 , min_samples: 14
# Day 0, Hour 6 :  2974 , min_samples: 26
# Day 0, Hour 7 :  3888 , min_samples: 34
# Day 0, Hour 8 :  3138 , min_samples: 28
# Day 0, Hour 9 :  2211 , min_samples: 19
# Day 0, Hour 10 :  1953 , min_samples: 17
# Day 0, Hour 11 :  1929 , min_samples: 17
# Day 0, Hour 12 :  1945 , min_samples: 17
# Day 0, Hour 13 :  2294 , min_samples: 20
# Day 0, Hour 14 :  3117 , min_samples: 28
# Day 0, Hour 15 :  3818 , min_samples: 34
# Day 0, Hour 16 :  4962 , min_samples: 44
# Day 0, Hour 17 :  5574 , min_samples: 50
# Day 0, Hour 18 :  4725 , min_samples: 42
# Day 0, Hour 19 :  4386 , min_samples: 39
# Day 0, Hour 20 :  3573 , min_samples: 32
# Day 0, Hour 21 :  3079 , min_samples: 27
# Day 0, Hour 22 :  1976 , min_samples: 17
# Day 0, Hour 23 :  1091 , min_samples: 9
# Day 1, Hour 0 :  765 , min_samples: 6
# Day 1, Hour 1 :  367 , min_samples: 3
# Day 1, Hour 2 :  304 , min_samples: 2
# Day 1, Hour 3 :  516 , min_samples: 4
# Day 1, Hour 4 :  887 , min_samples: 7
# Day 1, Hour 5 :  1734 , min_samples: 15
# Day 1, Hour 6 :  3766 , min_samples: 33
# Day 1, Hour 7 :  5304 , min_samples: 47
# Day 1, Hour 8 :  4594 , min_samples: 41
# Day 1, Hour 9 :  2962 , min_samples: 26
# Day 1, Hour 10 :  2900 , min_samples: 26
# Day 1, Hour 11 :  2949 , min_samples: 26
# Day 1, Hour 12 :  2819 , min_samples: 25
# Day 1, Hour 13 :  3556 , min_samples: 32
# Day 1, Hour 14 :  4489 , min_samples: 40
# Day 1, Hour 15 :  6042 , min_samples: 54
# Day 1, Hour 16 :  7521 , min_samples: 67
# Day 1, Hour 17 :  8297 , min_samples: 74
# Day 1, Hour 18 :  7089 , min_samples: 63
# Day 1, Hour 19 :  6459 , min_samples: 58
# Day 1, Hour 20 :  6310 , min_samples: 56
# Day 1, Hour 21 :  5993 , min_samples: 53
# Day 1, Hour 22 :  3614 , min_samples: 32
# Day 1, Hour 23 :  1948 , min_samples: 17
# Day 2, Hour 0 :  899 , min_samples: 8
# Day 2, Hour 1 :  507 , min_samples: 4
# Day 2, Hour 2 :  371 , min_samples: 3
# Day 2, Hour 3 :  585 , min_samples: 5
# Day 2, Hour 4 :  1003 , min_samples: 9
# Day 2, Hour 5 :  1990 , min_samples: 17
# Day 2, Hour 6 :  4230 , min_samples: 38
# Day 2, Hour 7 :  5647 , min_samples: 50
# Day 2, Hour 8 :  5242 , min_samples: 47
# Day 2, Hour 9 :  3846 , min_samples: 34
# Day 2, Hour 10 :  3844 , min_samples: 34
# Day 2, Hour 11 :  3889 , min_samples: 35
# Day 2, Hour 12 :  3988 , min_samples: 35
# Day 2, Hour 13 :  4469 , min_samples: 40
# Day 2, Hour 14 :  5438 , min_samples: 48
# Day 2, Hour 15 :  7071 , min_samples: 63
# Day 2, Hour 16 :  8213 , min_samples: 73
# Day 2, Hour 17 :  9151 , min_samples: 82
# Day 2, Hour 18 :  8334 , min_samples: 75
# Day 2, Hour 19 :  7794 , min_samples: 70
# Day 2, Hour 20 :  7783 , min_samples: 70
# Day 2, Hour 21 :  6921 , min_samples: 62
# Day 2, Hour 22 :  4845 , min_samples: 43
# Day 2, Hour 23 :  2571 , min_samples: 23
# Day 3, Hour 0 :  792 , min_samples: 7
# Day 3, Hour 1 :  459 , min_samples: 4
# Day 3, Hour 2 :  342 , min_samples: 3
# Day 3, Hour 3 :  567 , min_samples: 5
# Day 3, Hour 4 :  861 , min_samples: 7
# Day 3, Hour 5 :  1454 , min_samples: 13
# Day 3, Hour 6 :  3179 , min_samples: 28
# Day 3, Hour 7 :  4159 , min_samples: 37
# Day 3, Hour 8 :  3616 , min_samples: 32
# Day 3, Hour 9 :  2654 , min_samples: 23
# Day 3, Hour 10 :  2370 , min_samples: 21
# Day 3, Hour 11 :  2516 , min_samples: 22
# Day 3, Hour 12 :  2657 , min_samples: 23
# Day 3, Hour 13 :  3301 , min_samples: 29
# Day 3, Hour 14 :  4083 , min_samples: 36
# Day 3, Hour 15 :  5182 , min_samples: 46
# Day 3, Hour 16 :  6149 , min_samples: 55
# Day 3, Hour 17 :  6951 , min_samples: 62
# Day 3, Hour 18 :  6637 , min_samples: 59
# Day 3, Hour 19 :  5929 , min_samples: 53
# Day 3, Hour 20 :  6345 , min_samples: 57
# Day 3, Hour 21 :  6585 , min_samples: 59
# Day 3, Hour 22 :  5370 , min_samples: 48
# Day 3, Hour 23 :  2909 , min_samples: 26
# Day 4, Hour 0 :  1367 , min_samples: 12
# Day 4, Hour 1 :  760 , min_samples: 6
# Day 4, Hour 2 :  513 , min_samples: 4
# Day 4, Hour 3 :  736 , min_samples: 6
# Day 4, Hour 4 :  932 , min_samples: 8
# Day 4, Hour 5 :  1382 , min_samples: 12
# Day 4, Hour 6 :  2836 , min_samples: 25
# Day 4, Hour 7 :  3943 , min_samples: 35
# Day 4, Hour 8 :  3648 , min_samples: 32
# Day 4, Hour 9 :  2732 , min_samples: 24
# Day 4, Hour 10 :  2599 , min_samples: 23
# Day 4, Hour 11 :  2816 , min_samples: 25
# Day 4, Hour 12 :  2978 , min_samples: 26
# Day 4, Hour 13 :  3535 , min_samples: 31
# Day 4, Hour 14 :  4087 , min_samples: 36
# Day 4, Hour 15 :  5354 , min_samples: 48
# Day 4, Hour 16 :  6259 , min_samples: 56
# Day 4, Hour 17 :  6790 , min_samples: 61
# Day 4, Hour 18 :  7258 , min_samples: 65
# Day 4, Hour 19 :  6247 , min_samples: 56
# Day 4, Hour 20 :  5165 , min_samples: 46
# Day 4, Hour 21 :  6265 , min_samples: 56
# Day 4, Hour 22 :  6708 , min_samples: 60
# Day 4, Hour 23 :  5393 , min_samples: 48
# Day 5, Hour 0 :  3027 , min_samples: 27
# Day 5, Hour 1 :  2479 , min_samples: 22
# Day 5, Hour 2 :  1577 , min_samples: 14
# Day 5, Hour 3 :  1013 , min_samples: 9
# Day 5, Hour 4 :  706 , min_samples: 6
# Day 5, Hour 5 :  704 , min_samples: 6
# Day 5, Hour 6 :  844 , min_samples: 7
# Day 5, Hour 7 :  1110 , min_samples: 9
# Day 5, Hour 8 :  1372 , min_samples: 12
# Day 5, Hour 9 :  1764 , min_samples: 15
# Day 5, Hour 10 :  2086 , min_samples: 18
# Day 5, Hour 11 :  2315 , min_samples: 20
# Day 5, Hour 12 :  2560 , min_samples: 23
# Day 5, Hour 13 :  2685 , min_samples: 24
# Day 5, Hour 14 :  3042 , min_samples: 27
# Day 5, Hour 15 :  4457 , min_samples: 40
# Day 5, Hour 16 :  5410 , min_samples: 48
# Day 5, Hour 17 :  5558 , min_samples: 50
# Day 5, Hour 18 :  6165 , min_samples: 55
# Day 5, Hour 19 :  5529 , min_samples: 49
# Day 5, Hour 20 :  4792 , min_samples: 43
# Day 5, Hour 21 :  5811 , min_samples: 52
# Day 5, Hour 22 :  6493 , min_samples: 58
# Day 5, Hour 23 :  5719 , min_samples: 51
# Day 6, Hour 0 :  4542 , min_samples: 40
# Day 6, Hour 1 :  2936 , min_samples: 26
# Day 6, Hour 2 :  1590 , min_samples: 14
# Day 6, Hour 3 :  1052 , min_samples: 9
# Day 6, Hour 4 :  685 , min_samples: 6
# Day 6, Hour 5 :  593 , min_samples: 5
# Day 6, Hour 6 :  669 , min_samples: 6
# Day 6, Hour 7 :  873 , min_samples: 7
# Day 6, Hour 8 :  1233 , min_samples: 11
# Day 6, Hour 9 :  1770 , min_samples: 15
# Day 6, Hour 10 :  2113 , min_samples: 19
# Day 6, Hour 11 :  2360 , min_samples: 21
# Day 6, Hour 12 :  2478 , min_samples: 22
# Day 6, Hour 13 :  2763 , min_samples: 24
# Day 6, Hour 14 :  2934 , min_samples: 26
# Day 6, Hour 15 :  3400 , min_samples: 30
# Day 6, Hour 16 :  3489 , min_samples: 31
# Day 6, Hour 17 :  3154 , min_samples: 28
# Day 6, Hour 18 :  2795 , min_samples: 25
# Day 6, Hour 19 :  2579 , min_samples: 23
# Day 6, Hour 20 :  2276 , min_samples: 20
# Day 6, Hour 21 :  2310 , min_samples: 20
# Day 6, Hour 22 :  1639 , min_samples: 14
# Day 6, Hour 23 :  1018 , min_samples: 9

# %%
new_df.shape
# Out:
# (564516, 5)

# %%
new_df = new_df[new_df['clusters'] > -1]

# visualisation of Monday by hours
fig = px.scatter_mapbox(new_df[(new_df['dayofweek'] == 2) & (new_df['hour'] == 4)], title='',
  lat="lat", lon="lon", color='clusters', mapbox_style="carto-positron", color_continuous_scale=['#323aa8','#db1616','#26ab26'],
  zoom=10, height=800)
fig.show()
# Out:
# <div>                            <div id="4e7ab6e2-d6c8-453c-aaea-d6a9506bd7f7" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e7ab6e2-d6c8-453c-aaea-d6a9506bd7f7")) {                    Plotly.newPlot(                        "4e7ab6e2-d6c8-453c-aaea-d6a9506bd7f7",                        [{"hovertemplate":"clusters=0<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","lat":[40.747,40.782,40.779,40.758,40.726,40.766,40.786,40.744,40.759,40.729,40.771,40.725,40.728,40.784,40.786,40.717,40.795,40.765,40.747,40.724,40.766,40.762,40.759,40.772,40.744,40.763,40.785,40.778,40.761,40.726,40.735,40.793,40.765,40.747,40.764,40.728,40.753,40.732,40.77,40.68,40.788,40.74,40.783,40.733,40.761,40.753,40.674,40.663,40.76,40.77,40.758,40.742,40.726,40.711,40.737,40.763,40.681,40.771,40.768,40.724,40.734,40.746,40.732,40.666,40.778,40.721,40.692,40.688,40.8,40.717,40.739,40.718,40.76,40.778,40.716,40.686,40.752,40.69,40.685,40.722,40.705,40.734,40.664,40.748,40.675,40.784,40.682,40.745,40.658,40.686,40.719,40.759,40.728,40.795,40.718,40.69,40.68,40.654,40.73,40.763,40.668,40.772,40.748,40.734,40.769,40.731,40.783,40.746,40.765,40.779,40.703,40.742,40.675,40.762,40.747,40.72,40.773,40.734,40.681,40.661,40.676,40.676,40.717,40.699,40.727,40.722,40.734,40.714,40.712,40.716,40.738,40.741,40.683,40.664,40.663,40.758,40.786,40.686,40.718,40.715,40.688,40.72,40.671,40.671,40.736,40.793,40.703,40.723,40.758,40.783,40.676,40.74,40.74,40.703,40.777,40.672,40.693,40.736,40.717,40.809,40.696,40.745,40.667,40.682,40.718,40.708,40.775,40.717,40.676,40.727,40.797,40.756,40.776,40.709,40.706,40.716,40.731,40.746,40.707,40.776,40.787,40.746,40.723,40.732,40.766,40.726,40.688,40.681,40.747,40.8,40.785,40.776,40.737,40.665,40.69,40.707,40.686,40.755,40.718,40.717,40.745,40.726,40.796,40.731,40.677,40.672,40.655,40.694,40.711,40.786,40.812,40.747,40.654,40.746,40.716,40.762,40.799,40.707,40.73,40.747,40.768,40.737,40.748,40.746,40.704,40.777,40.696,40.772,40.731,40.72,40.723,40.744,40.688,40.786,40.683,40.737,40.736,40.728,40.765,40.769,40.782,40.688,40.69,40.691,40.813,40.675,40.763,40.728,40.711,40.72,40.732,40.722,40.722,40.737,40.781,40.662,40.768,40.676,40.751,40.729,40.706,40.717,40.661,40.672,40.721,40.727,40.764,40.686,40.736,40.777,40.752,40.75,40.729,40.76,40.731,40.724,40.763,40.698,40.781,40.703,40.727,40.734,40.723,40.781,40.721,40.729,40.748,40.758,40.689,40.777,40.778,40.783,40.732,40.787,40.781,40.734,40.712,40.719,40.749,40.698,40.736,40.7,40.678,40.68,40.738,40.776,40.797,40.725,40.765,40.77,40.787,40.672,40.763,40.741,40.771,40.764,40.779,40.71,40.726,40.721,40.716,40.691,40.75,40.762,40.683,40.678,40.727,40.796,40.669,40.719,40.686,40.744,40.723,40.716,40.734,40.708,40.738,40.738,40.737,40.725,40.771,40.748,40.763,40.693,40.686,40.711,40.733,40.733,40.759,40.738,40.671,40.743,40.768,40.751,40.774,40.716,40.724,40.741,40.67,40.749,40.722,40.681,40.712,40.748,40.777,40.686,40.767,40.802,40.742,40.754,40.722,40.765,40.728,40.694,40.745,40.748,40.67,40.705,40.753,40.753,40.759,40.745,40.778,40.755,40.807,40.692,40.666,40.72,40.75,40.739,40.771,40.672,40.685,40.748,40.764,40.668,40.722,40.764,40.764,40.747,40.731,40.747,40.738,40.72,40.744,40.723,40.736,40.726,40.702,40.781,40.767,40.732,40.674,40.675,40.675,40.719,40.774,40.777,40.791,40.708,40.744,40.744,40.664,40.747,40.773,40.788,40.714,40.726,40.821,40.758,40.728,40.721,40.688,40.76,40.78,40.666,40.666,40.744,40.686,40.75,40.716,40.743,40.76,40.76,40.768,40.768,40.763,40.708,40.742,40.744,40.666,40.722,40.776,40.738,40.735,40.707,40.694,40.785,40.785,40.722,40.686,40.744,40.75,40.701,40.661,40.742,40.73,40.747,40.771,40.785,40.741,40.736,40.736,40.725,40.72,40.748,40.749,40.689,40.724,40.759,40.748,40.769,40.75,40.716,40.733,40.723,40.808,40.705,40.704,40.672,40.8 ...

# %%
new_df[(new_df['clusters'] == 1) & (new_df['hour'] == 10) & (new_df['dayofweek'] == 2)]
# Out:
#           lat      lon  dayofweek  hour clusters
# 13    40.7708 -73.8656          2    10        1
# 16    40.7704 -73.8652          2    10        1
# 57    40.7710 -73.8657          2    10        1
# 71    40.7710 -73.8660          2    10        1
# 116   40.7740 -73.8724          2    10        1
# ...       ...      ...        ...   ...      ...
# 3624  40.7708 -73.8657          2    10        1
# 3674  40.7731 -73.8856          2    10        1
# 3777  40.7741 -73.8731          2    10        1
# 3796  40.7709 -73.8658          2    10        1
# 3842  40.7710 -73.8659          2    10        1
#
# [89 rows x 5 columns]

# %%
# 3 decimals after lat et long is a enough precision, instead of 4. 2 is too large
new_df['lat'] = new_df['lat'].round(3)
new_df['lon'] = new_df['lon'].round(3)

# we group by and aggregate as count in a new col
new_df['nbcourses'] = 1
last_df = new_df.groupby(['lat','lon','dayofweek','hour','clusters']).count().sort_values('hour').reset_index() # aggreg will be only in nbcourses

# %%
last_df
# Out:
#            lat     lon  dayofweek  hour  clusters  nbcourses
# 0       40.610 -73.962          0     0         5          1
# 1       40.731 -73.978          2     0         0          1
# 2       40.731 -73.978          5     0         0          1
# 3       40.731 -73.978          6     0         0          1
# 4       40.731 -73.976          6     0         0          1
# ...        ...     ...        ...   ...       ...        ...
# 244072  40.758 -73.964          5    23         0          3
# 244073  40.779 -73.961          5    23         0          1
# 244074  40.738 -74.009          2    23         0          4
# 244075  40.712 -73.962          4    23         0          1
# 244076  40.741 -74.004          1    23         0          2
#
# [244077 rows x 6 columns]

# %%
last_df.to_csv(OUTPUT_FILE_NAME)
